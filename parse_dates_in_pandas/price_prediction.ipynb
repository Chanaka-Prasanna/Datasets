# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read data without using parse_dates
df = pd.read_csv('data.csv',low_memory=False)
df.head()
# Out:
#               Date  SalePrice
# 0  11/16/2006 0:00    66000.0
# 1   3/26/2004 0:00    57000.0
# 2   2/26/2004 0:00    10000.0
# 3   5/19/2011 0:00    38500.0
# 4   7/23/2009 0:00    11000.0

# %%
#So Extracting features will give you an error. Because date is not datetime object yet
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = dt['Date'].dt.day
df['DayOfWeek'] = df['Date'].dt.dayofweek
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 #So Extracting features will give you an error. Because date is not datetime object yet
# ----> 2 df['Year'] = df['Date'].dt.year
#       3 df['Month'] = df['Date'].dt.month
#       4 df['Day'] = dt['Date'].dt.day
#
# File /lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File /lib/python3.11/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       412698 non-null  object
#  1   SalePrice  412698 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 4.7+ MB

# %%
#Ploting upto 1000th records
fig, ax = plt.subplots()
ax.scatter(df["Date"][:1000],df["SalePrice"][:1000])

# %%
#Ploting upto 10th records to understand x axis's behaviour
fig, ax = plt.subplots()
ax.scatter(df["Date"][:10],df["SalePrice"][:10])

# %%
#Read data with using parse_dates
df_test = pd.read_csv('data.csv',low_memory=False,parse_dates=['Date'])
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       412698 non-null  datetime64[ns]
#  1   SalePrice  412698 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.3 MB

# %%
#Ploting upto 1000th records
fig, ax = plt.subplots()
ax.scatter(df_test["Date"][:1000],df_test["SalePrice"][:1000])

# %% [markdown]
# Reffer the docs for more information on extracting the features of date.
#
# Link - https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#time-date-components

# %%
# Extracting features and save as new columns
df_test['Year'] = df_test['Date'].dt.year
df_test['Month'] = df_test['Date'].dt.month
df_test['Day'] = df_test['Date'].dt.day
df_test['DayOfWeek'] = df_test['Date'].dt.dayofweek

# %%
# See the first 50 records
df_test.head(50)
# Out:
#          Date  SalePrice  Year  Month  Day  DayOfWeek
# 0  2006-11-16    66000.0  2006     11   16          3
# 1  2004-03-26    57000.0  2004      3   26          4
# 2  2004-02-26    10000.0  2004      2   26          3
# 3  2011-05-19    38500.0  2011      5   19          3
# 4  2009-07-23    11000.0  2009      7   23          3
# 5  2008-12-18    26500.0  2008     12   18          3
# 6  2004-08-26    21000.0  2004      8   26          3
# 7  2005-11-17    27000.0  2005     11   17          3
# 8  2009-08-27    21500.0  2009      8   27          3
# 9  2007-08-09    65000.0  2007      8    9          3
# 10 2008-08-21    24000.0  2008      8   21          3
# 11 2006-08-24    22500.0  2006      8   24          3
# 12 2005-10-20    36000.0  2005     10   20          3
# 13 2006-01-26    30500.0  2006      1   26          3
# 14 2006-01-03    28000.0  2006      1    3          1
# 15 2006-11-16    19000.0  2006     11   16          3
# ...
